# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **NAME = RITU SINGH**
# I have just completed my masters and right now exploring Data Science field. I found it pretty attractive and hence want to pursue my career in Data Science.

# %% [markdown]
# *I am interesting in data science because,it just improve various fields ,we can resolve many industry problems by data science. Further it deals with analysing data to find insights of it and that want I love to do.*

# %% [markdown]
# ### Adding to variables

# %%
a=2
b=3
print("a+b =")
print(a+b)
# Out:
# a+b =
# 5

# %% [markdown]
# |a |b |sum|
# |--|--|---|
# |1 |1 |2  |
# |1 |2 |3  |
# |2 |3 |5  |

# %% [markdown]
# - <font color=red>In the above table show the sum to a and b :</font>
#     - <font color=blue>when value of a=1 and b=1 ,sum is 2
#     - <font color=blue> when value of a=1 and b=2 ,sum is 3
#     -  <font color=blue>when value of a=2 and b=3 ,sum is 5

# %% [markdown]
# ![image.png](attachment:b94a1cac-f7a7-4b08-b8b4-74320f90e7a7.png)

# %% [markdown]
# ## Link :
# [click here to jupyter](https://jupyter.org/try)
